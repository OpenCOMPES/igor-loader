# %% [markdown]
# # <font color='red'>COPY THIS FILE TO THE ROOT OF THE UPLOAD, AND RENAME IT.</font>

# %% [markdown]
# ## Template for loading Static_ARPES data from the Phoibos detector at FHI Berlin.
# The data are loaded as igor_binarywave and converted to xarray
# <!-- following another conversion to the [NeXus format](https://manual.nexusformat.org/classes/contributed_definitions/NXmpes.html#nxmpes) -->
# <!-- using the [Nomad Parser Nexus](https://github.com/nomad-coe/nomad-parser-nexus). -->

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import ipywidgets as widgets
from ipywidgets import interact
from igor2 import binarywave
from pathlib import Path
from igor_loader import static_analysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Load class
sp=static_analysis()

# %% [markdown]
# Single Sweep Scan

# %%
datapath="Tutorial_data/"
run=11
name="WSe2_"

# %%
sp.load(datapath,name,run)
# dims=['Energy','Angular'] 
# sp.edit() #If you need to change the name of the dimensions

# %%
# sp.save("test.nxs")

# %%
# sp.data.plot() #Visualize the data
sp.edc() #check the edcs
# Out:
# VBox(children=(FloatSlider(value=0.0, description='Angular', max=14.91573033707865, min=-15.0, step=0.08426966…
# Output()

# %% [markdown]
# Axis Scan (Fixed and Sweep)

# %%
datapath="//nap32/topfloor/StaticARPES/Data/ARPES/2026/202601/20260123/"
run=8
name="WSe2_"

# %%
sp.load(datapath,name,run)

# %%
#Visualize the data
def update(i=0):
    sp.stacked[i].plot()
i_slider = widgets.IntSlider(value=1,min=1,max=len(sp.stacked),step=1,description='i')
interact(update, i=i_slider)
# Out:
# interactive(children=(IntSlider(value=1, description='i', max=13, min=1), Output()), _dom_classes=('widget-int…
# <function __main__.update(i=0)>

# %%
len(sp.stacked)
# Out:
# 13

# %% [markdown]
# Tilt Scan (old version of files)

# %%
# datapath="test_data/"
# fst=14 #first scan
# last=35 #last scan
# sp.load_tilt_old(datapath,fst,last)

# %%
# #Individual Visualization 
# def update(i=1):
#     sp.tilt[str(i)].plot()

# i_slider = widgets.IntSlider(value=0,min=0,max=len(sp.tilt)-1,step=1,description='i')

# interact(update, i=i_slider)

# %%
# Combine Tilt scan in a single xarray
# stacked = sp.combine_tilts()

# %%
# Tool for checking the fermi surface
# sp.tilt_map(stacked)

# %% [markdown]
# Tilt New

# %%
datapath="//nap32/topfloor/StaticARPES/Data/ARPES/2026/202602/20260209/"
run=14
name="FGT_"

# %%
sp.load(datapath,name,run)

# %%
# sp.tilt_map()
sp.Chunk_3D()
# Out:
# interactive(children=(FloatSlider(value=16.00479852, description='Energy', max=17.00959704, min=15.0, step=0.0…

# %%
# #Individual Visualization 
def update(i=1):
    sp.stacked[i].plot()

i_slider = widgets.IntSlider(value=0,min=0,max=len(sp.stacked)-1,step=1,description='i')

interact(update, i=i_slider)
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=6), Output()), _dom_classes=('widget-interact',)…
# <function __main__.update(i=1)>
